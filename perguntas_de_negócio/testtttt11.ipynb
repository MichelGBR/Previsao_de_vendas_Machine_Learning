# %%
import pandas as pd

data = pd.read_csv("C:/Users/marce/ansel/Desktop/df.csv")

data.head()
# Out:
#    Código da área       Estado Localidade Tamanho do mercado  Lucros($)  \
# 0             203  Connecticut      Leste            Pequeno      107.0
# 1             203  Connecticut      Leste            Pequeno       75.0
# 2             203  Connecticut      Leste            Pequeno      105.0
# 3             203  Connecticut      Leste            Pequeno      104.0
# 4             203  Connecticut      Leste            Pequeno      104.0
#
#    Despesas + lucros  Vendas  Custo dos produtos vendidos  Despesas totais  \
# 0              176.0   292.0                        116.0             69.0
# 1              135.0   225.0                         90.0             60.0
# 2              174.0   289.0                        115.0             69.0
# 3              135.0   223.0                         90.0             56.0
# 4              135.0   223.0                         90.0             56.0
#
#    Investimento em Marketing  Valor do estoque  Lucro esperado  CPV esperado  \
# ...

# %%
newdata = data.rename(columns= {"Código da área": "codigo_area" , "Estado": "estado" , "Localidade" : "localidade"
                      ,"Tamanho do mercado" : "tamanho_do_mercado", "Lucros($)": "lucros", "Despesas + lucros":
                       "despesas_mais_lucros", "Vendas": "vendas", "Custo dos produtos vendidos": "custo_dos_produtos_vendidos"
                       , "Despesas totais" : "despesas_totais", "Investimento em Marketing" : "investimento_em_marketing",
                       "Valor do estoque": "valor_do_estoque", "Lucro esperado" :  "lucro_esperado", "CPV esperado" : "cpv_esperado",
                       "Despesa + lucro esperado":"despesa_mais_lucro_esperado", "Venda esperada": "venda_esperada","ID do produto":
                        "id_produto", 'Data': "data_pedido","Tipo do produto": "tipo_do_produto", "Produto": "produto", "Tipo":"tipo" })

# %%
newdata.head()
# Out:
#    codigo_area       estado localidade tamanho_do_mercado  lucros  \
# 0          203  Connecticut      Leste            Pequeno   107.0
# 1          203  Connecticut      Leste            Pequeno    75.0
# 2          203  Connecticut      Leste            Pequeno   105.0
# 3          203  Connecticut      Leste            Pequeno   104.0
# 4          203  Connecticut      Leste            Pequeno   104.0
#
#    despesas_mais_lucros  vendas  custo_dos_produtos_vendidos  despesas_totais  \
# 0                 176.0   292.0                        116.0             69.0
# 1                 135.0   225.0                         90.0             60.0
# 2                 174.0   289.0                        115.0             69.0
# 3                 135.0   223.0                         90.0             56.0
# 4                 135.0   223.0                         90.0             56.0
#
#    investimento_em_marketing  valor_do_estoque  lucro_esperado  cpv_esperado  \
# ...

# %%
newdata2 = (newdata["investimento_em_marketing"]<16)

newdata2.value_counts()
# Out:
# investimento_em_marketing
# True     1458
# False    1298
# Name: count, dtype: int64

# %%
"""5 - Qual a média de vendas em geral?"""

newdata["vendas"].describe()
# Out:
# count    2756.000000
# mean      124.209724
# std        54.183692
# min        23.000000
# 25%        83.000000
# 50%       119.000000
# 75%       159.000000
# max       292.000000
# Name: vendas, dtype: float64

# %%
"""3 - Quantos mercados em geral estão abaixo da média de marketing?"""

newdata2 = (newdata["investimento_em_marketing"]<16)

newdata2.value_counts()

# True = abaixo, False = acima
# Out:
# investimento_em_marketing
# True     1458
# False    1298
# Name: count, dtype: int64
