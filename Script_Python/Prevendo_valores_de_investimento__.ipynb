# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression 
from sklearn.model_selection import train_test_split

""" 
Area Code: Código da Loja;
State: Estado da Loja;
Market: Região da Loja;
Market Size: Tamanho da Loja;
Profit: Lucros em Dólares ($);
Margin: Lucro + Despesas Totais ($) OU Vendas - CPV ($);
Sales: Valores Adquiridos em Vendas ($);
COGS: Custo dos Produtos Vendidos ($);
Total Expenses: Despesas totais para colocar o produto à venda ($);
Marketing: Despesas com Marketing ($);
Inventory: Valor do Estoque do Produto no Momento da Venda ($);
Budget Profit: Lucro Esperado ($);
Budget COGS: CPV esperado ($);
Budget Margin: Lucro Esperado + Despesas Totais Esperadas ($) OU Vendas Esperadas - CPV Esperado ($);
Budget Sales: Valor Esperado Adquirido em Vendas ($);
ProductID: ID do produto;
Date: Data de venda;
Product Type: Categoria de Produto;
Product: Descrição do produto;
Type: Tipo; """

""" Limpeza e traducao dos dados para melhor leitura """
                                        
data = pd.read_csv("C:/Users/marce/Downloads/datasettt/sales.csv")

dataPT1 = data.replace(["East", "West", "South", "Central", "Caffe Latte", "Caffe Mocha","Chamomile", "Darjeeling", "Decaf Espresso",
                    "Decaf Irish Cream", "Earl Grey","Green Tea", "Lemon", "Mint", "Regular Espresso", "Coffee", "Espresso","Herbal Tea", "Tea",
                     "Small Market", "Major Market","Decaf", "Regular" ,  ], 
                    ["Leste", "Oeste", "Sul","Centro", "Café Latte", "Café mocha", "Camomila", "Folha de Darjeeling", "Café Decaf Espresso",
                    "Creme Irlandês descafeinado",  "Chá de conde cinza", "Chá verde","Limão", "Hortelã", "Café espresso", "Café", "Café espresso",
                     "Chá de ervas", "Chá ", "Pequeno", "Grande","Descafeinado", "Normal",  ])
                    
dataPT2 = dataPT1.rename(columns= {"Area Code" : "Código da área" , "State" : "Estado" , "Market" : "Localidade" , "Market Size" : "Tamanho do mercado"
                    , "Profit" : "Lucros($)" , "Sales" : "Vendas", "COGS" : "Custo dos produtos vendidos", "Total Expenses" : "Despesas totais", 
                    "Inventory": "Valor do estoque" , "Budget Profit" : "Lucro esperado", "Budget COGS" : "CPV esperado", "Budget Sales":
                    "Venda esperada", "ProductId" : "ID do produto", "Date": "Data", "Product Type": "Tipo do produto" , "Product":"Produto",
                    "Type" : "Tipo", "Marketing" : "Investimento em Marketing", "Margin" : "Despesas + lucros" , 
                    "Budget Margin" : "Despesa + lucro esperado" })

#Conjunto de dados original
data.head(10)
# Out:
#    Area Code        State Market   Market Size  Profit  Margin  Sales   COGS  \
# 0        203  Connecticut   East  Small Market   107.0   176.0  292.0  116.0
# 1        203  Connecticut   East  Small Market    75.0   135.0  225.0   90.0
# 2        203  Connecticut   East  Small Market   122.0   195.0  325.0  130.0
# 3        203  Connecticut   East  Small Market   105.0   174.0  289.0  115.0
# 4        203  Connecticut   East  Small Market   104.0   135.0  223.0   90.0
# 5        203  Connecticut   East  Small Market   104.0   135.0  223.0   90.0
# 6        203  Connecticut   East  Small Market   135.0   155.0  275.0  103.0
# 7        203  Connecticut   East  Small Market   171.0   188.0  334.0  125.0
# 8        203  Connecticut   East  Small Market   181.0   195.0  346.0  130.0
# 9        203  Connecticut   East  Small Market    15.0    31.0   51.0   20.0
#
#    Total Expenses  Marketing  Inventory  Budget Profit  Budget COGS  \
# 0            69.0       38.0      962.0          110.0        110.0
# 1            60.0       29.0     1148.0           90.0         80.0
# 2            73.0       42.0     1134.0          130.0        110.0
# 3            69.0       37.0     1166.0          110.0        100.0
# 4            56.0       29.0     1148.0           90.0         80.0
# 5            56.0       29.0     1139.0           90.0         80.0
# 6            64.0       33.0     1130.0          110.0         90.0
# 7            73.0       41.0     1119.0          130.0        100.0
# 8            73.0       42.0     1134.0          130.0        110.0
# 9            16.0        5.0      804.0           20.0         20.0
#
#    Budget Margin  Budget Sales  ProductId               Date Product Type  \
# 0          160.0         270.0          2  04/01/10 00:00:00       Coffee
# 1          130.0         210.0          2  07/01/10 00:00:00       Coffee
# 2          180.0         290.0          2  11/01/10 00:00:00       Coffee
# 3          160.0         260.0          2  12/01/10 00:00:00       Coffee
# 4          130.0         210.0          2  07/01/11 00:00:00       Coffee
# 5          130.0         210.0          2  08/01/11 00:00:00       Coffee
# 6          150.0         240.0          2  09/01/11 00:00:00       Coffee
# 7          160.0         260.0          2  10/01/11 00:00:00       Coffee
# 8          180.0         290.0          2  11/01/11 00:00:00       Coffee
# 9           30.0          50.0         13  06/01/10 00:00:00          Tea
#
#      Product     Type
# 0  Columbian  Regular
# 1  Columbian  Regular
# 2  Columbian  Regular
# 3  Columbian  Regular
# 4  Columbian  Regular
# 5  Columbian  Regular
# 6  Columbian  Regular
# 7  Columbian  Regular
# 8  Columbian  Regular
# 9  Green Tea  Regular

# %%
#Conjunto de dados traduzidos
dataPT2.head(10)
# Out:
#    Código da área       Estado Localidade Tamanho do mercado  Lucros($)  \
# 0             203  Connecticut      Leste            Pequeno      107.0
# 1             203  Connecticut      Leste            Pequeno       75.0
# 2             203  Connecticut      Leste            Pequeno      122.0
# 3             203  Connecticut      Leste            Pequeno      105.0
# 4             203  Connecticut      Leste            Pequeno      104.0
# 5             203  Connecticut      Leste            Pequeno      104.0
# 6             203  Connecticut      Leste            Pequeno      135.0
# 7             203  Connecticut      Leste            Pequeno      171.0
# 8             203  Connecticut      Leste            Pequeno      181.0
# 9             203  Connecticut      Leste            Pequeno       15.0
#
#    Despesas + lucros  Vendas  Custo dos produtos vendidos  Despesas totais  \
# 0              176.0   292.0                        116.0             69.0
# 1              135.0   225.0                         90.0             60.0
# 2              195.0   325.0                        130.0             73.0
# 3              174.0   289.0                        115.0             69.0
# 4              135.0   223.0                         90.0             56.0
# 5              135.0   223.0                         90.0             56.0
# 6              155.0   275.0                        103.0             64.0
# 7              188.0   334.0                        125.0             73.0
# 8              195.0   346.0                        130.0             73.0
# 9               31.0    51.0                         20.0             16.0
#
#    Investimento em Marketing  Valor do estoque  Lucro esperado  CPV esperado  \
# 0                       38.0             962.0           110.0         110.0
# 1                       29.0            1148.0            90.0          80.0
# 2                       42.0            1134.0           130.0         110.0
# 3                       37.0            1166.0           110.0         100.0
# 4                       29.0            1148.0            90.0          80.0
# 5                       29.0            1139.0            90.0          80.0
# 6                       33.0            1130.0           110.0          90.0
# 7                       41.0            1119.0           130.0         100.0
# 8                       42.0            1134.0           130.0         110.0
# 9                        5.0             804.0            20.0          20.0
#
#    Despesa + lucro esperado  Venda esperada  ID do produto               Data  \
# 0                     160.0           270.0              2  04/01/10 00:00:00
# 1                     130.0           210.0              2  07/01/10 00:00:00
# 2                     180.0           290.0              2  11/01/10 00:00:00
# 3                     160.0           260.0              2  12/01/10 00:00:00
# 4                     130.0           210.0              2  07/01/11 00:00:00
# 5                     130.0           210.0              2  08/01/11 00:00:00
# 6                     150.0           240.0              2  09/01/11 00:00:00
# 7                     160.0           260.0              2  10/01/11 00:00:00
# 8                     180.0           290.0              2  11/01/11 00:00:00
# 9                      30.0            50.0             13  06/01/10 00:00:00
#
#   Tipo do produto    Produto    Tipo
# 0            Café  Columbian  Normal
# 1            Café  Columbian  Normal
# 2            Café  Columbian  Normal
# 3            Café  Columbian  Normal
# 4            Café  Columbian  Normal
# 5            Café  Columbian  Normal
# 6            Café  Columbian  Normal
# 7            Café  Columbian  Normal
# 8            Café  Columbian  Normal
# 9            Chá   Chá verde  Normal

# %%
dataPT2.isnull().sum() #Sem valores nulos e duplicados (já verificado)
# Out:
# Código da área                 0
# Estado                         0
# Localidade                     0
# Tamanho do mercado             0
# Lucros($)                      0
# Despesas + lucros              0
# Vendas                         0
# Custo dos produtos vendidos    0
# Despesas totais                0
# Investimento em Marketing      0
# Valor do estoque               0
# Lucro esperado                 0
# CPV esperado                   0
# Despesa + lucro esperado       0
# Venda esperada                 0
# ID do produto                  0
# Data                           0
# Tipo do produto                0
# Produto                        0
# Tipo                           0
# dtype: int64

# %%
dataPT2["Data"].head()  # ANTES
# Out:
# 0    04/01/10 00:00:00
# 1    07/01/10 00:00:00
# 2    11/01/10 00:00:00
# 3    12/01/10 00:00:00
# 4    07/01/11 00:00:00
# Name: Data, dtype: object

# %%
dataPT2["Data"] = pd.to_datetime(dataPT2["Data"], format= "mixed", dayfirst = True) #Organizando datas - DEPOIS

dataPT2["Data"].head()
# Out:
# 0   2010-01-04
# 1   2010-01-07
# 2   2010-01-11
# 3   2010-01-12
# 4   2011-01-07
# Name: Data, dtype: datetime64[ns]

# %%
""" Observando o boxplot de vendas, lucros e investimento em marketing, percebe-se que há muitos outliers acima ou abaixo da média, 
o que pode se tornar um problema, pois queremos que o nosso ML seja o mais acertivo possível. Portanto, irei remover eles. """


data_box = dataPT2[['Lucros($)', 'Vendas',
       'Investimento em Marketing',]]

plt.figure(figsize= (12,12))
sns.boxplot(data= data_box)
plt.show()

# %%
# Boxplot limpos:

new_data = (dataPT2["Vendas"]<=350)

dataPT2 = dataPT2[new_data]

sns.boxplot(dataPT2["Vendas"])
# Out:
# <Axes: >

# %%
new_data2 = (dataPT2["Lucros($)"]<=107) & (dataPT2["Lucros($)"]>= -20) #Limpando os números positivos/negativos


dataPT2 = dataPT2[new_data2]

sns.boxplot(dataPT2["Lucros($)"])
# Out:
# <Axes: >

# %%
new_data3 = (dataPT2["Investimento em Marketing"]<= 38)

dataPT2 = dataPT2[new_data3]

sns.boxplot(dataPT2["Investimento em Marketing"])
# Out:
# <Axes: >

# %%
#Mantendo colunas que daremos mais atencao de como elas se relacionam

data_num = dataPT2.select_dtypes(exclude= ["object" , "datetime64"]) #Transformando apenas em colunas com números


data_num = data_num[['Lucros($)', 'Vendas',
       'Investimento em Marketing',]]

datacorr = data_num.corr() #Vendo a relacao das informacoes

datacorr
# Out:
#                            Lucros($)    Vendas  Investimento em Marketing
# Lucros($)                   1.000000  0.801921                   0.539543
# Vendas                      0.801921  1.000000                   0.908682
# Investimento em Marketing   0.539543  0.908682                   1.000000

# %%
""" Vendo a relacao das informacoes por meio do heatmap, há uma taxa muito alta em vendas com investimento
no MKT."""

plt.figure(figsize=(10,10))
sns.heatmap(data_num.corr() , cmap= "Blues" , annot= True)
# Out:
# <Axes: >

# %%
""" Agora o principal objetivo é que o Machine Learning nos responda quanto o número x em 
investimento de marketing pode nos gerar de vendas, com base nos dados históricos """

x = np.array(dataPT2["Investimento em Marketing"])

x = x.reshape(-1, 1)
y = dataPT2["Vendas"]

#Gráfico de dispersao

plt.figure(figsize= (10,10))
plt.scatter(x, y , color= "Blue" , label = "Relacionamento de investimento em MKT e vendas")
plt.xlabel("Investimento em marketing")
plt.ylabel("Vendas")
plt.legend()
plt.show()

# %%
""" A linha da regressao linear nos mostra que o desfecho dessas duas é positivo! """

xtreino, xteste, ytreino, yteste = train_test_split(x, y ,test_size= 0.3, random_state= 42)

modelo_regre = LinearRegression()

modelo_regre.fit(xtreino, ytreino)


plt.figure(figsize= (10,10))
plt.scatter(x,y, color= "Purple" , label= "Relacionamento de investimento em MKT e vendas")
plt.plot(x, modelo_regre.predict(x), color= "Red", label="Previsao")
plt.xlabel("Investimento em MKT")
plt.ylabel("Lucros($)")
plt.legend()
plt.show()

# %%
#Utilizando o seaborn

sns.lmplot(x= "Investimento em Marketing", y = "Vendas" , data= dataPT2, height = 10)

# %%
#Modelo de Machine Learning

investimento_mkt = np.array([[79]]) #Valor aleatório (79)
vendas = modelo_regre.predict(investimento_mkt)

print("Se você investir:", investimento_mkt , ", Você terá:", vendas , "de vendas.")
# Out:
# Se você investir: [[79]] , Você terá: [510.72783769] de vendas.

# %%
# Mais exemplos:

investimento_mkt = np.array([[12]]) 
vendas = modelo_regre.predict(investimento_mkt)

print("Se você investir:", investimento_mkt , ", Você terá:", vendas , "de vendas.")
# Out:
# Se você investir: [[12]] , Você terá: [98.25498674] de vendas.

# %%
investimento_mkt = np.array([[37]]) 
vendas = modelo_regre.predict(investimento_mkt)

print("Se você investir:", investimento_mkt , ", Você terá:", vendas , "de vendas.")
# Out:
# Se você investir: [[37]] , Você terá: [252.16276695] de vendas.

# %%
investimento_mkt = np.array([[146]]) 
vendas = modelo_regre.predict(investimento_mkt)

print("Se você investir:", investimento_mkt , ", Você terá:", vendas , "de vendas.")
# Out:
# Se você investir: [[146]] , Você terá: [923.20068865] de vendas.

# %%
investimento_mkt = np.array([[97]]) 
vendas = modelo_regre.predict(investimento_mkt)

print("Se você investir:", investimento_mkt , ", Você terá:", vendas , "de vendas.")
# Out:
# Se você investir: [[97]] , Você terá: [621.54143944] de vendas.

# %%
newdata0.head() #Aqui é uma renomeacao de titulo das colunas para ficar mais fácil ao tópico "perguntas de negócio"
# Out:
#    codigo_area       estado localidade tamanho_do_mercado  lucros  \
# 0          203  Connecticut      Leste            Pequeno   107.0
# 1          203  Connecticut      Leste            Pequeno    75.0
# 3          203  Connecticut      Leste            Pequeno   105.0
# 4          203  Connecticut      Leste            Pequeno   104.0
# 5          203  Connecticut      Leste            Pequeno   104.0
#
#    despesas_mais_lucros  vendas  custo_dos_produtos_vendidos  despesas_totais  \
# 0                 176.0   292.0                        116.0             69.0
# 1                 135.0   225.0                         90.0             60.0
# 3                 174.0   289.0                        115.0             69.0
# 4                 135.0   223.0                         90.0             56.0
# 5                 135.0   223.0                         90.0             56.0
#
#    investimento_em_marketing  valor_do_estoque  lucro_esperado  cpv_esperado  \
# 0                       38.0             962.0           110.0         110.0
# 1                       29.0            1148.0            90.0          80.0
# 3                       37.0            1166.0           110.0         100.0
# 4                       29.0            1148.0            90.0          80.0
# 5                       29.0            1139.0            90.0          80.0
#
#    despesa_mais_lucro_esperado  venda_esperada  id_produto data_pedido  \
# 0                        160.0           270.0           2  2010-01-04
# 1                        130.0           210.0           2  2010-01-07
# 3                        160.0           260.0           2  2010-01-12
# 4                        130.0           210.0           2  2011-01-07
# 5                        130.0           210.0           2  2011-01-08
#
#   tipo_do_produto    produto    tipo
# 0            Café  Columbian  Normal
# 1            Café  Columbian  Normal
# 3            Café  Columbian  Normal
# 4            Café  Columbian  Normal
# 5            Café  Columbian  Normal
