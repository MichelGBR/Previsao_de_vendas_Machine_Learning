# %%
#o calculo do boxplot é feito atraves dos percentis (mediana dos números)
"""temos o q1, mediana e q3 nos percentis, e com box plot nós temos o Ls(limite superior)
e o li (limite inferior)
ls e li é os pontos fora da curva da mediana que obtemos no q1 e q3 "pontos distante das distribuicoes dos dados"
o calculo de ls é feito atráves de: q3 + 1,5 .(q3 - q1)
já o de li é q1 - 1,5 .(q3 - q1) """

import pandas as pd
import matplotlib.pyplot as plt


dados = pd.read_csv("C:/Users/marce/ansel/Desktop/cod/athlete_events.csv")

dados.head()

dados.boxplot(column= ["Age" , "Weight" , "Height"])

plt.show()
