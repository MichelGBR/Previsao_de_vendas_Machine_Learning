# %%
import pandas as pd
import matplotlib.pyplot as plt

dados = pd.read_csv('C:/Users/marce/ansel/Desktop/cod/athlete_events.csv')

dados.head(10)

"""Observei as primeiras linhas e concluí que temos informações desnecessárias, por exemplo:
Games e Season, na própria coluna Games já é informado em qual Season ocorreu."""
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 5   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 6   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 7   5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 8   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
# 9   5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season         City          Sport  \
# 0  CHN  1992 Summer  1992  Summer    Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer       London           Judo
# 2  DEN  1920 Summer  1920  Summer    Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer        Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter      Calgary  Speed Skating
# 5  NED  1988 Winter  1988  Winter      Calgary  Speed Skating
# 6  NED  1992 Winter  1992  Winter  Albertville  Speed Skating
# 7  NED  1992 Winter  1992  Winter  Albertville  Speed Skating
# 8  NED  1994 Winter  1994  Winter  Lillehammer  Speed Skating
# 9  NED  1994 Winter  1994  Winter  Lillehammer  Speed Skating
#
#                                 Event Medal
# 0         Basketball Men's Basketball   NaN
# 1        Judo Men's Extra-Lightweight   NaN
# 2             Football Men's Football   NaN
# 3         Tug-Of-War Men's Tug-Of-War  Gold
# 4    Speed Skating Women's 500 metres   NaN
# 5  Speed Skating Women's 1,000 metres   NaN
# 6    Speed Skating Women's 500 metres   NaN
# 7  Speed Skating Women's 1,000 metres   NaN
# 8    Speed Skating Women's 500 metres   NaN
# 9  Speed Skating Women's 1,000 metres   NaN

# %%
dados.isnull().sum()

"""Aqui verifiquei as colunas que tivessem mais "NaN", nosso objetivo é manter aquelas que tenham esses dados faltantes
visualizando apenas as que sejam úteis para informar quem é o atleta olímpico."""
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# Games          0
# City           0
# Event          0
# Medal     231333
# dtype: int64

# %%
dados = pd.read_csv('C:/Users/marce/ansel/Desktop/cod/athlete_events.csv')

#Apagando colunas que não sejam necessárias
dados.drop(["NOC" , "Year" , "Sport", "Season", ] , axis = 1 , inplace=True)

"""Definindo os valores "Nan" na coluna medalha como "Nenhuma". """

dados ["Medal"].fillna("Nenhuma" , inplace= True)

""""Traduzindo a linha medalha e temporrada"""
medalha_dadosPTBR = dados.replace(["Gold" , "Silver"], ["Ouro" , "Prata",])

"""Objetivo aqui é traduzir, ou seja, substituir as palavras para o PT-BR (apenas das colunas e medalhas
pois esse conjunto de dados é muito longo e há muitas selecoes diferentes)."""

dados_traduzidos = medalha_dadosPTBR.rename(columns={"Name" : "Nome" , "Sex" : "Sexo" , "Age" : "Idade" , "Height" : "Altura", "Weight": "Peso" ,
                      "Team" : "Time" , "Games" : "Jogos/temporada" , "City" : "Cidade" , "Event" : "Eventos" , "Medal" : "Medalha"})

dados_traduzidos.head(50)
# Out:
# C:\Users\marce\AppData\Local\Temp\ipykernel_15488\4163716112.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dados ["Medal"].fillna("Nenhuma" , inplace= True)
#     ID                                Nome Sexo  Idade  Altura  Peso  \
# 0    1                           A Dijiang    M   24.0   180.0  80.0
# 1    2                            A Lamusi    M   23.0   170.0  60.0
# 2    3                 Gunnar Nielsen Aaby    M   24.0     NaN   NaN
# 3    4                Edgar Lindenau Aabye    M   34.0     NaN   NaN
# 4    5            Christine Jacoba Aaftink    F   21.0   185.0  82.0
# 5    5            Christine Jacoba Aaftink    F   21.0   185.0  82.0
# 6    5            Christine Jacoba Aaftink    F   25.0   185.0  82.0
# 7    5            Christine Jacoba Aaftink    F   25.0   185.0  82.0
# 8    5            Christine Jacoba Aaftink    F   27.0   185.0  82.0
# 9    5            Christine Jacoba Aaftink    F   27.0   185.0  82.0
# 10   6                     Per Knut Aaland    M   31.0   188.0  75.0
# 11   6                     Per Knut Aaland    M   31.0   188.0  75.0
# 12   6                     Per Knut Aaland    M   31.0   188.0  75.0
# 13   6                     Per Knut Aaland    M   31.0   188.0  75.0
# 14   6                     Per Knut Aaland    M   33.0   188.0  75.0
# 15   6                     Per Knut Aaland    M   33.0   188.0  75.0
# 16   6                     Per Knut Aaland    M   33.0   188.0  75.0
# 17   6                     Per Knut Aaland    M   33.0   188.0  75.0
# 18   7                        John Aalberg    M   31.0   183.0  72.0
# 19   7                        John Aalberg    M   31.0   183.0  72.0
# 20   7                        John Aalberg    M   31.0   183.0  72.0
# 21   7                        John Aalberg    M   31.0   183.0  72.0
# 22   7                        John Aalberg    M   33.0   183.0  72.0
# 23   7                        John Aalberg    M   33.0   183.0  72.0
# 24   7                        John Aalberg    M   33.0   183.0  72.0
# 25   7                        John Aalberg    M   33.0   183.0  72.0
# 26   8  Cornelia "Cor" Aalten (-Strannood)    F   18.0   168.0   NaN
# 27   8  Cornelia "Cor" Aalten (-Strannood)    F   18.0   168.0   NaN
# 28   9                    Antti Sami Aalto    M   26.0   186.0  96.0
# 29  10      Einar Ferdinand "Einari" Aalto    M   26.0     NaN   NaN
# 30  11                  Jorma Ilmari Aalto    M   22.0   182.0  76.5
# 31  12                   Jyri Tapani Aalto    M   31.0   172.0  70.0
# 32  13                  Minna Maarit Aalto    F   30.0   159.0  55.5
# 33  13                  Minna Maarit Aalto    F   34.0   159.0  55.5
# 34  14      Pirjo Hannele Aalto (Mattila-)    F   32.0   171.0  65.0
# 35  15                Arvo Ossian Aaltonen    M   22.0     NaN   NaN
# 36  15                Arvo Ossian Aaltonen    M   22.0     NaN   NaN
# 37  15                Arvo Ossian Aaltonen    M   30.0     NaN   NaN
# 38  15                Arvo Ossian Aaltonen    M   30.0     NaN   NaN
# 39  15                Arvo Ossian Aaltonen    M   34.0     NaN   NaN
# 40  16            Juhamatti Tapio Aaltonen    M   28.0   184.0  85.0
# 41  17             Paavo Johannes Aaltonen    M   28.0   175.0  64.0
# 42  17             Paavo Johannes Aaltonen    M   28.0   175.0  64.0
# 43  17             Paavo Johannes Aaltonen    M   28.0   175.0  64.0
# 44  17             Paavo Johannes Aaltonen    M   28.0   175.0  64.0
# 45  17             Paavo Johannes Aaltonen    M   28.0   175.0  64.0
# 46  17             Paavo Johannes Aaltonen    M   28.0   175.0  64.0
# 47  17             Paavo Johannes Aaltonen    M   28.0   175.0  64.0
# 48  17             Paavo Johannes Aaltonen    M   28.0   175.0  64.0
# 49  17             Paavo Johannes Aaltonen    M   32.0   175.0  64.0
#
#               Time Jogos/temporada          Cidade  \
# 0            China     1992 Summer       Barcelona
# 1            China     2012 Summer          London
# 2          Denmark     1920 Summer       Antwerpen
# 3   Denmark/Sweden     1900 Summer           Paris
# 4      Netherlands     1988 Winter         Calgary
# 5      Netherlands     1988 Winter         Calgary
# 6      Netherlands     1992 Winter     Albertville
# 7      Netherlands     1992 Winter     Albertville
# 8      Netherlands     1994 Winter     Lillehammer
# 9      Netherlands     1994 Winter     Lillehammer
# 10   United States     1992 Winter     Albertville
# 11   United States     1992 Winter     Albertville
# 12   United States     1992 Winter     Albertville
# 13   United States     1992 Winter     Albertville
# 14   United States     1994 Winter     Lillehammer
# 15   United States     1994 Winter     Lillehammer
# 16   United States     1994 Winter     Lillehammer
# 17   United States     1994 Winter     Lillehammer
# 18   United States     1992 Winter     Albertville
# 19   United States     1992 Winter     Albertville
# 20   United States     1992 Winter     Albertville
# 21   United States     1992 Winter     Albertville
# 22   United States     1994 Winter     Lillehammer
# 29                Swimming Men's 400 metres Freestyle  Nenhuma
# 30           Cross Country Skiing Men's 30 kilometres  Nenhuma
# 31                            Badminton Men's Singles  Nenhuma
# 32                         Sailing Women's Windsurfer  Nenhuma
# 33                         Sailing Women's Windsurfer  Nenhuma
# 34             Biathlon Women's 7.5 kilometres Sprint  Nenhuma
# 35             Swimming Men's 200 metres Breaststroke  Nenhuma
# 36             Swimming Men's 400 metres Breaststroke  Nenhuma
# 37             Swimming Men's 200 metres Breaststroke   Bronze
# 38             Swimming Men's 400 metres Breaststroke   Bronze
# 39             Swimming Men's 200 metres Breaststroke  Nenhuma
# 40                        Ice Hockey Men's Ice Hockey   Bronze
# 41             Gymnastics Men's Individual All-Around   Bronze
# 42                   Gymnastics Men's Team All-Around     Ouro
# 43                    Gymnastics Men's Floor Exercise  Nenhuma
# 44                       Gymnastics Men's Horse Vault     Ouro
# 45                     Gymnastics Men's Parallel Bars  Nenhuma
# 46                    Gymnastics Men's Horizontal Bar  Nenhuma
# 47                             Gymnastics Men's Rings  Nenhuma
# 48                   Gymnastics Men's Pommelled Horse     Ouro
# 49             Gymnastics Men's Individual All-Around  Nenhuma

# %%
"""Depois de ter limpado todos os dados substituindo pela sua traducao ou apagando uma coluna desnecessária,
é hora de descobrir o que vamos fazer em colunas que não temos informacao sobre, como a de 'Altura' e 'Peso'
que obteve muitos 'NaN"""

dados = pd.read_csv('C:/Users/marce/ansel/Desktop/cod/athlete_events.csv')

dados_traduzidos.head(50)

"""Como não temos dados exatos sobre a idade e altura dos atletas, decidi fazer uma análise com historograma"""


"""o meu cálculo do historograma funcionou da seguinte forma:
pegamos o minímo e máximo: nesse caso, idades(exemplo). vamos supor que as idades é min 10 e max 90
fazemos o calculo de 90 - 10 = 80, como vou botar 100 colunas, devemos dividir 80 / 100 = 0,8
ou seja, pegamos do ponto min (10) somamos + 0,8 = 10.8, tendo uma variacao de 0,8 em 0,8 anos"""

dados_traduzidos.hist(column= "Idade" , bins = 100)
plt.show()

"""Após analisar, pude ver que de 22 até 26 anos é onde ocorre o maior número presente de idades,
tendo cerca de mais de 210 mil atletas nessa faixa"""

dados_traduzidos.hist(column= "Altura" , bins = 100)
plt.show()

"""Já a altura, conseguimos confirmar que há maior número entre 1.70 até 1.80,
com mais de 10 mil ateltas nessa faixa"""

"""Como não temos um número exato pelo conjunto de dados serem de grande número, optei
por realizar a média e chegar em número aproximado."""

dados_traduzidos ["Idade"].fillna(dados_traduzidos["Idade"].mean(), inplace= True)
dados_traduzidos ["Altura"].fillna(dados_traduzidos["Altura"].mean(), inplace= True)

dados_traduzidos.head(50)
# Out:
# C:\Users\marce\AppData\Local\Temp\ipykernel_15488\1192434166.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dados_traduzidos ["Idade"].fillna(dados_traduzidos["Idade"].mean(), inplace= True)
# C:\Users\marce\AppData\Local\Temp\ipykernel_15488\1192434166.py:33: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dados_traduzidos ["Altura"].fillna(dados_traduzidos["Altura"].mean(), inplace= True)
#     ID                                Nome Sexo  Idade     Altura       Peso  \
# 0    1                           A Dijiang    M   24.0  180.00000  80.000000
# 1    2                            A Lamusi    M   23.0  170.00000  60.000000
# 2    3                 Gunnar Nielsen Aaby    M   24.0  175.33897  70.702393
# 3    4                Edgar Lindenau Aabye    M   34.0  175.33897  70.702393
# 4    5            Christine Jacoba Aaftink    F   21.0  185.00000  82.000000
# 5    5            Christine Jacoba Aaftink    F   21.0  185.00000  82.000000
# 6    5            Christine Jacoba Aaftink    F   25.0  185.00000  82.000000
# 7    5            Christine Jacoba Aaftink    F   25.0  185.00000  82.000000
# 8    5            Christine Jacoba Aaftink    F   27.0  185.00000  82.000000
# 9    5            Christine Jacoba Aaftink    F   27.0  185.00000  82.000000
# 10   6                     Per Knut Aaland    M   31.0  188.00000  75.000000
# 11   6                     Per Knut Aaland    M   31.0  188.00000  75.000000
# 12   6                     Per Knut Aaland    M   31.0  188.00000  75.000000
# 13   6                     Per Knut Aaland    M   31.0  188.00000  75.000000
# 14   6                     Per Knut Aaland    M   33.0  188.00000  75.000000
# 15   6                     Per Knut Aaland    M   33.0  188.00000  75.000000
# 16   6                     Per Knut Aaland    M   33.0  188.00000  75.000000
# 17   6                     Per Knut Aaland    M   33.0  188.00000  75.000000
# 18   7                        John Aalberg    M   31.0  183.00000  72.000000
# 19   7                        John Aalberg    M   31.0  183.00000  72.000000
# 20   7                        John Aalberg    M   31.0  183.00000  72.000000
# 21   7                        John Aalberg    M   31.0  183.00000  72.000000
# 22   7                        John Aalberg    M   33.0  183.00000  72.000000
# 23   7                        John Aalberg    M   33.0  183.00000  72.000000
# 24   7                        John Aalberg    M   33.0  183.00000  72.000000
# 25   7                        John Aalberg    M   33.0  183.00000  72.000000
# 26   8  Cornelia "Cor" Aalten (-Strannood)    F   18.0  168.00000  70.702393
# 27   8  Cornelia "Cor" Aalten (-Strannood)    F   18.0  168.00000  70.702393
# 28   9                    Antti Sami Aalto    M   26.0  186.00000  96.000000
# 29  10      Einar Ferdinand "Einari" Aalto    M   26.0  175.33897  70.702393
# 30  11                  Jorma Ilmari Aalto    M   22.0  182.00000  76.500000
# 31  12                   Jyri Tapani Aalto    M   31.0  172.00000  70.000000
# 32  13                  Minna Maarit Aalto    F   30.0  159.00000  55.500000
# 33  13                  Minna Maarit Aalto    F   34.0  159.00000  55.500000
# 34  14      Pirjo Hannele Aalto (Mattila-)    F   32.0  171.00000  65.000000
# 35  15                Arvo Ossian Aaltonen    M   22.0  175.33897  70.702393
# 36  15                Arvo Ossian Aaltonen    M   22.0  175.33897  70.702393
# 37  15                Arvo Ossian Aaltonen    M   30.0  175.33897  70.702393
# 38  15                Arvo Ossian Aaltonen    M   30.0  175.33897  70.702393
# 39  15                Arvo Ossian Aaltonen    M   34.0  175.33897  70.702393
